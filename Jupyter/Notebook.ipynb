# %%
import pandas as pd

# Create a comprehensive list of data science learning resources
resources_data = {
    'Platform': [
        'Coursera',
        'edX',
        'DataCamp',
        'Kaggle',
        'Fast.ai',
        'Google Cloud Skills Boost',
        'Microsoft Learn',
        'Udacity',
        'HackerRank',
        'LeetCode',
        'Towards Data Science',
        'Khan Academy'
    ],
    'Type': [
        'Online Course',
        'Online Course',
        'Interactive Platform',
        'Competition & Learning',
        'Free Course',
        'Hands-on Labs',
        'Free Learning Path',
        'Nanodegree',
        'Practice Problems',
        'Coding Challenges',
        'Articles & Tutorials',
        'Fundamentals'
    ],
    'Focus Area': [
        'ML, Statistics, Python',
        'Data Science, AI',
        'Python, R, SQL',
        'Practical ML Projects',
        'Deep Learning',
        'Cloud ML & Data',
        'Azure ML & AI',
        'Career-focused Programs',
        'SQL, Python, Statistics',
        'Algorithms, Data Structures',
        'Latest DS Trends',
        'Math & Statistics Basics'
    ],
    'Cost': [
        'Paid (Free Audit)',
        'Paid (Free Audit)',
        'Freemium',
        'Free',
        'Free',
        'Free',
        'Free',
        'Paid',
        'Freemium',
        'Freemium',
        'Free',
        'Free'
    ],
    'Best For': [
        'Certificates & Structured Learning',
        'University-level Courses',
        'Hands-on Practice',
        'Real-world Projects',
        'Deep Learning Enthusiasts',
        'Cloud-based ML',
        'Microsoft Ecosystem',
        'Career Transition',
        'Interview Prep',
        'Algorithm Practice',
        'Staying Updated',
        'Building Foundation'
    ]
}

# Create DataFrame
df_resources = pd.DataFrame(resources_data)

# Display the table with styling
print("=" * 150)
print("DATA SCIENCE LEARNING RESOURCES".center(150))
print("=" * 150)
print()

# Display the full table
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

print(df_resources.to_string(index=True))

print()
print("=" * 150)
print(f"Total Resources: {len(df_resources)}")
print("=" * 150)
